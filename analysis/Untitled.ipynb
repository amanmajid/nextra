# %%
library(dplyr)
library(waterfalls)
library(ggplot2)
library(cowplot)
library(data.table)

options(warn=-1)

# %%
#install.packages('cowplot')

# %%
results = read.csv(file = '../outputs/results/merged_capacity_results.csv')

# remove gas storage
results[results$node == "israel_gas_storage", "node"] <- "israel_natural_gas"
results[results$technology == "Gas Reservoir", "technology"] <- "Gas"

# change ccgt category
results[results$node == "west_bank_ccgt", "node"] <- "west_bank_natural_gas"
results[results$node == "jordan_ccgt", "node"] <- "jordan_natural_gas"
results[results$node == "israel_ccgt", "node"] <- "israel_natural_gas"

# get caps by scenario
capacity_by_scenario = results %>% group_by(node,scenario) %>% summarise_all(list(max),na.rm=TRUE)

# add colours 
tech = c("Battery","Diesel","Gas","Solar","Coal","Wind","Shale")
cols = c("lightskyblue","lightcoral","lightgray","lightgoldenrod1","black","mediumaquamarine","mistyrose3")
colour_df = data.frame(row.names=tech,val=cols)

# add colour codes
unique_technologies = unique(capacity_by_scenario$technology)
count = 1
for (val in unique_technologies) {
    capacity_by_scenario[capacity_by_scenario$technology == val, "colours"] <- colour_df[val,]
    count = count + 1
}

# %%
head(capacity_by_scenario, n = 3)
# Out:
#   node                 scenario commodity   timestep value technology territory
# 1 gaza_battery_storage BAS      electricity 8760       0   Battery    Gaza
# 2 gaza_battery_storage BAU      electricity 8760     949   Battery    Gaza
# 3 gaza_battery_storage COO      electricity 8760       0   Battery    Gaza
#   colours
# 1 lightskyblue
# 2 lightskyblue
# 3 lightskyblue

# %%
oms_waterfall <- function(capacity_by_scenario,scenario_to_filter) {
  
  # select specific columns
  scenario_results = capacity_by_scenario #%>% select(node,scenario,value)
    
  # filter results by scenario
  scenario_results = filter(scenario_results, scenario == scenario_to_filter, value > 0) #
    
  # convert capacity to integer
  scenario_results$value = as.integer(scenario_results$value)
    
  # adjust units to GW
  scenario_results$value = round(scenario_results$value * 10**-3, 2)
    
  # sort by name
  scenario_results = arrange(scenario_results, node, value)
    
  # TEST!!
  #scenario_results[scenario_results$node == 'jordan_solar','value'] <- -3.5
    
  # colours
  colours = scenario_results %>% select(node,colours)
  colours = colours$colours
    
  # add territory code
  count = 1
  list_territory_code = c()
  for (v in scenario_results$territory) {
        list_territory_code = c(list_territory_code, paste(substr(v,1,1), count, sep=""))
        count = count + 1
  }
  scenario_results$node = list_territory_code
    
  # make plot
  plot_n <- waterfall(scenario_results %>% select(node,value), 
                  calc_total = TRUE,
                  rect_border = NA,
                  total_rect_color = "orange",
                  total_rect_text_color = "black",
                  rect_text_size=0.8,
                  linetype = NA,
                  fill_by_sign = FALSE,
                  fill_colours = colours,
                  draw_axis.x = 'none',
                  rect_width=1,
                  ) + 
                    # define ggplot theme
                    theme_classic() + 
                        # define labels
                        labs(title = scenario_to_filter,
                            #subtitle = "INSTALLED CAPACITY IN 2030 (MW)",
                            y = 'Installed capacity (GW)', 
                            x = '',
                            ) +
                        # plot configs
                        theme(text = element_text(size=10),
                              #axis.text.x=element_blank(),
                              #axis.text.x = element_text(angle=90,hjust=1)
                             ) + ylim(-5,65) + geom_hline(yintercept=0, linetype="dashed", color="black")
  return(plot_n)
}

# %%
plot1 = oms_waterfall(capacity_by_scenario,scenario_to_filter='BAS')
plot2 = oms_waterfall(capacity_by_scenario,scenario_to_filter='COO')
#plot3 = oms_waterfall(capacity_by_scenario,scenario_to_filter='EAG')
plot4 = oms_waterfall(capacity_by_scenario,scenario_to_filter='BAU')
plot5 = oms_waterfall(capacity_by_scenario,scenario_to_filter='NCO')

plot_grid(plot1, plot2, plot4, plot5, labels = "AUTO", nrow = 3, ncol = 2) #plot3,

ggsave("../outputs/figures/oms_waterfall.png", width = 20, height = 25, units = "cm")
# Out:
# plot without title

# %%
scenario_results = capacity_by_scenario #%>% select(node,scenario,value)
head(scenario_results,n=4)
# Out:
#   node                 scenario commodity   timestep value technology territory
# 1 gaza_battery_storage BAS      electricity 8760        0  Battery    Gaza
# 2 gaza_battery_storage BAU      electricity 8760      949  Battery    Gaza
# 3 gaza_battery_storage COO      electricity 8760        0  Battery    Gaza
# 4 gaza_battery_storage EAG      electricity 8760     2028  Battery    Gaza
#   colours
# 1 lightskyblue
# 2 lightskyblue
# 3 lightskyblue
# 4 lightskyblue

# %%
# select specific columns
scenario_results = capacity_by_scenario #%>% select(node,scenario,value)
# filter results by scenario
scenario_results = filter(scenario_results, scenario == scenario_to_filter, value > 0) #
# convert capacity to integer
scenario_results$value = as.integer(scenario_results$value)
# adjust units to GW
scenario_results$value = round(scenario_results$value * 10**-3, 2)
# sort by name
scenario_results = arrange(scenario_results, node, value)

scenario_results
# Out:
#    node                      scenario commodity   timestep value technology
# 1  gaza_battery_storage      EAG      electricity 8760      2.03 Battery
# 2  gaza_natural_gas          EAG      electricity 8760      0.23 Gas
# 3  gaza_solar                EAG      electricity 8760      2.54 Solar
# 4  israel_battery_storage    EAG      electricity 8760      1.64 Battery
# 5  israel_natural_gas        EAG      electricity 8760     12.08 Gas
# 6  israel_solar              EAG      electricity 8760     16.03 Solar
# 7  israel_wind               EAG      electricity 8760      0.35 Wind
# 8  jordan_battery_storage    EAG      electricity 8760      0.59 Battery
# 9  jordan_natural_gas        EAG      electricity 8760      4.43 Gas
# 10 jordan_shale              EAG      electricity 8760      0.86 Shale
# 11 jordan_solar              EAG      electricity 8760      4.41 Solar
# 12 jordan_wind               EAG      electricity 8760      1.49 Wind
# 13 west_bank_battery_storage EAG      electricity 8760      0.16 Battery
# 14 west_bank_solar           EAG      electricity 8760      1.50 Solar
# 15 west_bank_wind            EAG      electricity 8760      0.05 Wind
#    territory colours
# 1  Gaza      lightskyblue
# 2  Gaza      lightgray
# 3  Gaza      lightgoldenrod1
# 4  Israel    lightskyblue
# 5  Israel    lightgray
# 6  Israel    lightgoldenrod1
# 7  Israel    mediumaquamarine
# 8  Jordan    lightskyblue
# 9  Jordan    lightgray
# 10 Jordan    mistyrose3
# 11 Jordan    lightgoldenrod1
# 12 Jordan    mediumaquamarine
# 13 West Bank lightskyblue
# 14 West Bank lightgoldenrod1
# 15 West Bank mediumaquamarine

# %%
count = 1
list_territory_code = c()
for (v in scenario_results$territory) {
    list_territory_code = c(list_territory_code, paste(substr(v,1,1), count, sep=""))
    count = count + 1
}

# %%
# select specific columns
scenario_results = capacity_by_scenario

# filter results by scenario
scenario_results = filter(scenario_results, scenario == scenario_to_filter) # , value > 0

scenario_results
# Out:
#    node                      scenario commodity   timestep value technology
# 1  gaza_battery_storage      EAG      electricity 8760      2028 Battery
# 2  gaza_diesel               EAG      electricity 8760         0 Diesel
# 3  gaza_natural_gas          EAG      electricity 8760       231 Gas
# 4  gaza_solar                EAG      electricity 8760      2535 Solar
# 5  israel_battery_storage    EAG      electricity 8760      1638 Battery
# 6  israel_coal               EAG      electricity 8760         0 Coal
# 7  israel_diesel             EAG      electricity 8760         0 Diesel
# 8  israel_natural_gas        EAG      electricity 8760     12081 Gas
# 9  israel_solar              EAG      electricity 8760     16031 Solar
# 10 israel_wind               EAG      electricity 8760       352 Wind
# 11 jordan_battery_storage    EAG      electricity 8760       590 Battery
# 12 jordan_coal               EAG      electricity 8760         0 Coal
# 13 jordan_diesel             EAG      electricity 8760         0 Diesel
# 14 jordan_natural_gas        EAG      electricity 8760      4432 Gas
# 15 jordan_shale              EAG      electricity 8760       862 Shale
# 16 jordan_solar              EAG      electricity 8760      4413 Solar
# 17 jordan_wind               EAG      electricity 8760      1487 Wind
# 18 west_bank_battery_storage EAG      electricity 8760       155 Battery
# 19 west_bank_coal            EAG      electricity 8760         0 Coal
# 20 west_bank_diesel          EAG      electricity 8760         0 Diesel
# 21 west_bank_natural_gas     EAG      electricity 8760         0 Gas
# 22 west_bank_solar           EAG      electricity 8760      1500 Solar
# 23 west_bank_wind            EAG      electricity 8760        50 Wind
#    territory colours
# 1  Gaza      lightskyblue
# 2  Gaza      lightcoral
# 3  Gaza      lightgray
# 4  Gaza      lightgoldenrod1
# 5  Israel    lightskyblue
# 6  Israel    black
# 7  Israel    lightcoral
# 8  Israel    lightgray
# 9  Israel    lightgoldenrod1
# 10 Israel    mediumaquamarine
# 11 Jordan    lightskyblue
# 12 Jordan    black
# 13 Jordan    lightcoral
# 14 Jordan    lightgray
# 15 Jordan    mistyrose3
# 16 Jordan    lightgoldenrod1
# 17 Jordan    mediumaquamarine
# 18 West Bank lightskyblue
# 19 West Bank black
# 20 West Bank lightcoral
# 21 West Bank lightgray
# 22 West Bank lightgoldenrod1
# 23 West Bank mediumaquamarine

# %%
oms_waterfall <- function(capacity_by_scenario,scenario_to_filter) {
    
    # ************************************************************************* ----
    # Params ----
    # ************************************************************************* ----
    
    ylim_max =             65
    axis_steps =           10
    top_label_distance =   ylim_max * 0.04
    box_label_threshold =  5
    label_decimals =       1
    
    # define colours
    plotting_colours = c(
                        # Gas
                        '#85929e',
                        # Solar
                        '#f4d03f',
                        # Shale
                        '#82e0aa',
                        # Diesel,
                        '#bb8fce',
                        # Coal
                        '#566573',
                        # Battery
                        '#f1948a',
                        # Wind
                        '#5dade2'
                        )

    regions_to_plot = c("Gaza", "West Bank", "Jordan", "Israel")
    technologies_to_plot = c("Gas", "Solar", "Shale", "Diesel", "Coal", "Battery", "Wind")
    
    # ************************************************************************* ----
    # Original data ----
    # ************************************************************************* ----

    # df <- 
    #   data.frame(
    #     x.axis.Var = rep(c("GZA", "WBK", "JOR", "ISR"), 4),
    #     cat.Var = rep(c("Wind", "Solar", "Battery" , "Gas"), each = 4),
    #     values = c(40.9, 500, 300, 200, # Wind
    #                300, 200, 300, 250, # Solar
    #                50, 50, 50, 50, # Battery
    #                100, 80, 200, 150   # Gas (BASE VALUE: IMPORTANT!)
    #                )
    #   )


    # select specific columns
    scenario_results = capacity_by_scenario

    # filter results by scenario
    scenario_results = filter(scenario_results, scenario == scenario_to_filter) # , value > 0

    df <- 
      data.frame(
        x.axis.Var = rep(regions_to_plot, length(technologies_to_plot)),
        cat.Var = rep(technologies_to_plot, each = 4)
      )

    df$values = -999

    for(i in 1:nrow(df)) {       # for-loop over rows
      tmp_df = filter(scenario_results, technology == df[i,]$cat.Var, territory == df[i,]$x.axis.Var)

      if (dim(tmp_df)[1] == 0) {
        df[i,]$values = 0
      } else {
        df[i,]$values = round(tmp_df$value/1000,label_decimals) # convert to GW
      }
    }
    
    # ************************************************************************* ----
    # Data for Waterfall Chart ----
    # ************************************************************************* ----

    df.tmp <- df %>%
      # \_Set the factor levels in the order you want ----
      mutate(
        x.axis.Var = factor(x.axis.Var,
                            levels = regions_to_plot),
        cat.Var = factor(cat.Var,
                            levels = technologies_to_plot)
      ) %>%
      # \_Sort by Group and Category ----
      arrange(x.axis.Var, desc(cat.Var)) %>%
      # \_Get the start and end points of the bars ----
      mutate(end.Bar = cumsum(values),
             start.Bar = c(0, head(end.Bar, -1))) %>%
      # \_Add a new Group called 'Total' with total by category ----
      rbind(
        df %>%
          # \___Sum by Categories ----
          group_by(cat.Var) %>% 
          summarise(values = sum(values)) %>%
          # \___Create new Group: 'Total' ----
          mutate(
            x.axis.Var = "Total",
            cat.Var = factor(cat.Var,
                             levels = technologies_to_plot)
          ) %>%
          # \___Sort by Group and Category ----
          arrange(x.axis.Var, desc(cat.Var)) %>%
          # \___Get the start and end points of the bars ----
          mutate(end.Bar = cumsum(values),
                 start.Bar = c(0, head(end.Bar, -1))) %>%
          # \___Put variables in the same order ----
          select(names(df),end.Bar,start.Bar)
      ) %>%
      # \_Get numeric index for the groups ----
      mutate(group.id = group_indices(., x.axis.Var)) %>%
      # \_Create new variable with total by group ----
      group_by(x.axis.Var) %>%
      mutate(total.by.x = sum(values)) %>%
      # \_Order the columns ----
      select(x.axis.Var, cat.Var, group.id, start.Bar, values, end.Bar, total.by.x)

    # ************************************************************************* ----
    # Plot ----
    # ************************************************************************* ----

    ggplot(df.tmp, aes(x = group.id, fill = cat.Var)) + 
      # \_Simple Waterfall Chart ----
      geom_rect(aes(x = group.id,
                    xmin = group.id - 0.25, # control bar gap width
                    xmax = group.id + 0.25, 
                    ymin = end.Bar,
                    ymax = start.Bar),
                color="black", 
                alpha=0.95) + 
      # \_Lines Between Bars ----
      geom_segment(aes(x=ifelse(group.id == last(group.id),
                                last(group.id),
                                group.id+0.25), 
                       xend=ifelse(group.id == last(group.id),
                                   last(group.id),
                                   group.id+0.75), 
                       y=ifelse(cat.Var == "Gas",
                                end.Bar,
                                # these will be removed once we set the y limits
                                max(end.Bar)*2), 
                       yend=ifelse(cat.Var == "Gas",
                                   end.Bar,
                                   # these will be removed once we set the y limits
                                   max(end.Bar)*2)), 
                   colour="black") +
      # \_Numbers inside bars (each category) ----
      geom_text(
        mapping = 
          aes(
            label = ifelse(values < box_label_threshold, 
                           "",
                           ifelse(nchar(values) == 3,
                                  as.character(values),
                                  as.character(values)
                                  )
                           ),
            y = rowSums(cbind(start.Bar,values/2))
            ),
        color = "black",
        fontface = "bold"
        ) + 
      # \_Total for each category above bars ----
      geom_text(
        mapping = 
          aes(
            label = ifelse(cat.Var != "Gas", 
                           "",
                           ifelse(nchar(total.by.x) == 3,
                                  as.character(total.by.x),
                                  as.character(total.by.x)
                                )
                          ),
            y = end.Bar + top_label_distance
          ),
        color = "black",
        fontface = "bold"
      ) + 
      # \_Change colors ----
      scale_fill_manual(values=plotting_colours) +
      # \_Change y axis to same scale as original ----
      scale_y_continuous(
        expand=c(0,0),
        limits = c(0, ylim_max),
        breaks = seq(0, ylim_max, axis_steps),
        labels = ifelse(nchar(seq(0, ylim_max, axis_steps)) < 4,
                        as.character(seq(0, ylim_max, axis_steps)),
                        seq(0, ylim_max, axis_steps)
                        )
      ) +
      # \_Add tick marks on x axis to look like the original plot ----
      scale_x_continuous(
        expand=c(0,0),
        limits = c(min(df.tmp$group.id)-0.5,max(df.tmp$group.id)+0.5),
        breaks = c(min(df.tmp$group.id)-0.5,
                   unique(df.tmp$group.id), 
                   unique(df.tmp$group.id) + 0.5
                   ),
        labels = 
          c("", 
            as.character(unique(df.tmp$x.axis.Var)), 
            rep(c(""), length(unique(df.tmp$x.axis.Var)))
          )
      ) +
      labs(
        title = scenario_to_filter,
        y = 'Installed capacity (GW)',
      ) +
      # \_Theme options to make it look like the original plot ----
      theme(
        text = element_text(size = 14, color = "black"),
        axis.text = element_text(size = 10, color = "black", face = "bold"),
        axis.text.y = element_text(margin = margin(r = 0.3, unit = "cm")),
        axis.ticks.x =
          element_line(color =
                         c("black",
                           rep(NA, length(unique(df.tmp$x.axis.Var))),
                           rep("black", length(unique(df.tmp$x.axis.Var))-1)
                         )
                       ),
        axis.line = element_line(colour = "black", size = 0.5),
        axis.ticks.length = unit(.15, "cm"),
        axis.title.x =       element_blank(),
        #axis.title.y =       element_blank(),
        panel.background =   element_blank(),
        #plot.margin =        unit(c(1, 1, 1, 1), "lines"),
        legend.text =        element_text(size = 10, 
                                          color = "black",
                                          face = "bold",
                                          margin = margin(l = 0.25, unit = "cm")
                                          ),
        legend.title =       element_blank()
      )
  #return(temp_C)
}

# %%
p1 = oms_waterfall(capacity_by_scenario,scenario_to_filter='BAS')
p2 = oms_waterfall(capacity_by_scenario,scenario_to_filter='COO')
p3 = oms_waterfall(capacity_by_scenario,scenario_to_filter='BAU')
p4 = oms_waterfall(capacity_by_scenario,scenario_to_filter='NCO')

plot_grid(p1, p2, p3, p4, labels = "AUTO", nrow = 2, ncol = 2) #plot3,
ggsave("../outputs/figures/oms_waterfall.png", width = 30, height = 20, units = "cm")
# Out:
# plot without title

# %%
# ************************************************************************* ----
# Packages ----
# ************************************************************************* ----

library("ggplot2")
library("dplyr")

# ************************************************************************* ----
# Params ----
# ************************************************************************* ----

scenario_to_filter =   'BAS'
ylim_max =             70
axis_steps =           10
top_label_distance =   ylim_max * 0.04

# define colours
plotting_colours = c(
                    # Gas
                    '#85929e',
                    # Solar
                    '#f4d03f',
                    # Shale
                    '#82e0aa',
                    # Diesel,
                    '#bb8fce',
                    # Coal
                    '#566573',
                    # Battery
                    '#f1948a',
                    # Wind
                    '#5dade2'
                    )

regions_to_plot = c("Gaza", "West Bank", "Jordan", "Israel")
technologies_to_plot = c("Gas", "Solar", "Shale", "Diesel", "Coal", "Battery", "Wind")

# ************************************************************************* ----
# Original data ----
# ************************************************************************* ----

# df <- 
#   data.frame(
#     x.axis.Var = rep(c("GZA", "WBK", "JOR", "ISR"), 4),
#     cat.Var = rep(c("Wind", "Solar", "Battery" , "Gas"), each = 4),
#     values = c(40.9, 500, 300, 200, # Wind
#                300, 200, 300, 250, # Solar
#                50, 50, 50, 50, # Battery
#                100, 80, 200, 150   # Gas (BASE VALUE: IMPORTANT!)
#                )
#   )


# select specific columns
scenario_results = capacity_by_scenario

# filter results by scenario
scenario_results = filter(scenario_results, scenario == scenario_to_filter) # , value > 0

df <- 
  data.frame(
    x.axis.Var = rep(regions_to_plot, length(technologies_to_plot)),
    cat.Var = rep(technologies_to_plot, each = 4)
  )

df$values = -999

for(i in 1:nrow(df)) {       # for-loop over rows
  tmp_df = filter(scenario_results, technology == df[i,]$cat.Var, territory == df[i,]$x.axis.Var)
  
  if (dim(tmp_df)[1] == 0) {
    df[i,]$values = 0
  } else {
    df[i,]$values = round(tmp_df$value/1000,2) # convert to GW
  }
}

# ************************************************************************* ----
# Data for Waterfall Chart ----
# ************************************************************************* ----

df.tmp <- df %>%
  # \_Set the factor levels in the order you want ----
  mutate(
    x.axis.Var = factor(x.axis.Var,
                        levels = regions_to_plot),
    cat.Var = factor(cat.Var,
                        levels = technologies_to_plot)
  ) %>%
  # \_Sort by Group and Category ----
  arrange(x.axis.Var, desc(cat.Var)) %>%
  # \_Get the start and end points of the bars ----
  mutate(end.Bar = cumsum(values),
         start.Bar = c(0, head(end.Bar, -1))) %>%
  # \_Add a new Group called 'Total' with total by category ----
  rbind(
    df %>%
      # \___Sum by Categories ----
      group_by(cat.Var) %>% 
      summarise(values = sum(values)) %>%
      # \___Create new Group: 'Total' ----
      mutate(
        x.axis.Var = "Total",
        cat.Var = factor(cat.Var,
                         levels = technologies_to_plot)
      ) %>%
      # \___Sort by Group and Category ----
      arrange(x.axis.Var, desc(cat.Var)) %>%
      # \___Get the start and end points of the bars ----
      mutate(end.Bar = cumsum(values),
             start.Bar = c(0, head(end.Bar, -1))) %>%
      # \___Put variables in the same order ----
      select(names(df),end.Bar,start.Bar)
  ) %>%
  # \_Get numeric index for the groups ----
  mutate(group.id = group_indices(., x.axis.Var)) %>%
  # \_Create new variable with total by group ----
  group_by(x.axis.Var) %>%
  mutate(total.by.x = sum(values)) %>%
  # \_Order the columns ----
  select(x.axis.Var, cat.Var, group.id, start.Bar, values, end.Bar, total.by.x)

# ************************************************************************* ----
# Plot ----
# ************************************************************************* ----

ggplot(df.tmp, aes(x = group.id, fill = cat.Var)) + 
  # \_Simple Waterfall Chart ----
  geom_rect(aes(x = group.id,
                xmin = group.id - 0.25, # control bar gap width
                xmax = group.id + 0.25, 
                ymin = end.Bar,
                ymax = start.Bar),
            color="black", 
            alpha=0.95) + 
  # \_Lines Between Bars ----
  geom_segment(aes(x=ifelse(group.id == last(group.id),
                            last(group.id),
                            group.id+0.25), 
                   xend=ifelse(group.id == last(group.id),
                               last(group.id),
                               group.id+0.75), 
                   y=ifelse(cat.Var == "Gas",
                            end.Bar,
                            # these will be removed once we set the y limits
                            max(end.Bar)*2), 
                   yend=ifelse(cat.Var == "Gas",
                               end.Bar,
                               # these will be removed once we set the y limits
                               max(end.Bar)*2)), 
               colour="black") +
  # \_Numbers inside bars (each category) ----
  geom_text(
    mapping = 
      aes(
        label = ifelse(values < 2, 
                       "",
                       ifelse(nchar(values) == 3,
                              as.character(values),
                              as.character(values)
                              )
                       ),
        y = rowSums(cbind(start.Bar,values/2))
        ),
    color = "black",
    fontface = "bold"
    ) + 
  # \_Total for each category above bars ----
  geom_text(
    mapping = 
      aes(
        label = ifelse(cat.Var != "Gas", 
                       "",
                       ifelse(nchar(total.by.x) == 3,
                              as.character(total.by.x),
                              as.character(total.by.x)
                            )
                      ),
        y = end.Bar + top_label_distance
      ),
    color = "black",
    fontface = "bold"
  ) + 
  # \_Change colors ----
  scale_fill_manual(values=plotting_colours) +
  # \_Change y axis to same scale as original ----
  scale_y_continuous(
    expand=c(0,0),
    limits = c(0, ylim_max),
    breaks = seq(0, ylim_max, axis_steps),
    labels = ifelse(nchar(seq(0, ylim_max, axis_steps)) < 4,
                    as.character(seq(0, ylim_max, axis_steps)),
                    seq(0, ylim_max, axis_steps)
                    )
  ) +
  # \_Add tick marks on x axis to look like the original plot ----
  scale_x_continuous(
    expand=c(0,0),
    limits = c(min(df.tmp$group.id)-0.5,max(df.tmp$group.id)+0.5),
    breaks = c(min(df.tmp$group.id)-0.5,
               unique(df.tmp$group.id), 
               unique(df.tmp$group.id) + 0.5
               ),
    labels = 
      c("", 
        as.character(unique(df.tmp$x.axis.Var)), 
        rep(c(""), length(unique(df.tmp$x.axis.Var)))
      )
  ) +
  labs(
    title = scenario_to_filter,
    y = 'Installed capacity (GW)',
  ) +
  # \_Theme options to make it look like the original plot ----
  theme(
    text = element_text(size = 14, color = "black"),
    axis.text = element_text(size = 10, color = "black", face = "bold"),
    axis.text.y = element_text(margin = margin(r = 0.3, unit = "cm")),
    axis.ticks.x =
      element_line(color =
                     c("black",
                       rep(NA, length(unique(df.tmp$x.axis.Var))),
                       rep("black", length(unique(df.tmp$x.axis.Var))-1)
                     )
                   ),
    axis.line = element_line(colour = "black", size = 0.5),
    axis.ticks.length = unit(.15, "cm"),
    axis.title.x =       element_blank(),
    #axis.title.y =       element_blank(),
    panel.background =   element_blank(),
    plot.margin =        unit(c(1, 1, 1, 1), "lines"),
    legend.text =        element_text(size = 10, 
                                      color = "black",
                                      face = "bold",
                                      margin = margin(l = 0.25, unit = "cm")
                                      ),
    legend.title =       element_blank()
  )

ggsave("../outputs/figures/oms_waterfall.png", width = 20, height = 15, units = "cm")
# Out:
# plot without title

# %%
df.tmp
# Out:
#    x.axis.Var cat.Var group.id start.Bar values end.Bar total.by.x
# 1  Gaza       Wind    1        0.00       0.00   0.00    0.34
# 2  Gaza       Battery 1        0.00       0.00   0.00    0.34
# 3  Gaza       Coal    1        0.00       0.00   0.00    0.34
# 4  Gaza       Diesel  1        0.00       0.00   0.00    0.34
# 5  Gaza       Shale   1        0.00       0.00   0.00    0.34
# 6  Gaza       Solar   1        0.00       0.00   0.00    0.34
# 7  Gaza       Gas     1        0.00       0.34   0.34    0.34
# 8  West Bank  Wind    2        0.34       0.05   0.39    0.91
# 9  West Bank  Battery 2        0.39       0.00   0.39    0.91
# 10 West Bank  Coal    2        0.39       0.00   0.39    0.91
# 11 West Bank  Diesel  2        0.39       0.00   0.39    0.91
# 12 West Bank  Shale   2        0.39       0.00   0.39    0.91
# 13 West Bank  Solar   2        0.39       0.00   0.39    0.91
# 14 West Bank  Gas     2        0.39       0.86   1.25    0.91
# 15 Jordan     Wind    3        1.25       0.00   1.25    5.18
# 16 Jordan     Battery 3        1.25       0.07   1.32    5.18
# 17 Jordan     Coal    3        1.32       0.00   1.32    5.18
# 18 Jordan     Diesel  3        1.32       0.00   1.32    5.18
# 19 Jordan     Shale   3        1.32       0.00   1.32    5.18
# 20 Jordan     Solar   3        1.32       0.70   2.02    5.18
# 21 Jordan     Gas     3        2.02       4.41   6.43    5.18
# 22 Israel     Wind    4        6.43       0.00   6.43   13.52
# 23 Israel     Battery 4        6.43       0.00   6.43   13.52
# 24 Israel     Coal    4        6.43       0.00   6.43   13.52
# 25 Israel     Diesel  4        6.43       0.00   6.43   13.52
# 26 Israel     Shale   4        6.43       0.00   6.43   13.52
# 27 Israel     Solar   4        6.43       0.00   6.43   13.52
# 28 Israel     Gas     4        6.43      13.52  19.95   13.52
# 29 Total      Wind    5        0.00       0.05   0.05   19.95
# 30 Total      Battery 5        0.05       0.07   0.12   19.95
# 31 Total      Coal    5        0.12       0.00   0.12   19.95
# 32 Total      Diesel  5        0.12       0.00   0.12   19.95
# 33 Total      Shale   5        0.12       0.00   0.12   19.95
# 34 Total      Solar   5        0.12       0.70   0.82   19.95
# 35 Total      Gas     5        0.82      19.13  19.95   19.95

# %%
unique(capacity_by_scenario$technology)
# Out:
# [1] "Battery" "Diesel"  "Gas"     "Solar"   "Coal"    "Wind"    "Shale"
