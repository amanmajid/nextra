# %%
library(ggplot2)
library(ggalluvial)

# %%
#install.packages("ggalluvial")

# %%
ggplot(data = vaccinations,
       aes(axis1 = survey, axis2 = response, y = freq)) +
  geom_alluvium(aes(fill = response)) +
  geom_stratum(aes(fill = response)) +
  geom_text(stat = "stratum",
            aes(label = after_stat(stratum))) +
  scale_x_discrete(limits = c("Survey", "Response"),
                   expand = c(0.15, 0.05)) +
  theme_void()
# Out:
# plot without title

# %%
head(vaccinations)
# Out:
#   survey    freq subject response start_date end_date
# 1 ms153_NSA 48   1       Always   2010-09-22 2010-10-25
# 2 ms153_NSA  9   2       Always   2010-09-22 2010-10-25
# 3 ms153_NSA 66   3       Always   2010-09-22 2010-10-25
# 4 ms153_NSA  1   4       Always   2010-09-22 2010-10-25
# 5 ms153_NSA 11   5       Always   2010-09-22 2010-10-25
# 6 ms153_NSA  1   6       Always   2010-09-22 2010-10-25

# %%
chords_data = read.csv('plots/chord_data/COO.csv')
chords_data
# Out:
#    from_territory   to_territory     value
# 1  Gaza supply      Gaza demand        556.0467
# 2  Israel supply    Gaza demand       1297.4424
# 3  Israel supply    Israel demand    23437.5725
# 4  Israel supply    Jordan demand     9797.8778
# 5  Israel supply    West Bank demand  4232.1285
# 6  Jordan supply    Israel demand    47113.0531
# 7  Jordan supply    Jordan demand    17631.4257
# 8  Jordan supply    West Bank demand   758.0346
# 9  Israel supply    Israel demand    19347.3930
# 10 West Bank supply Jordan demand      847.0137
# 11 West Bank supply West Bank demand  2138.6413

# %%
ggplot(data = chords_data,
       aes(axis1 = from_territory, 
           axis2 = to_territory, 
           y = value
          )
    ) +
    geom_alluvium(aes(fill = from_territory),
                  alpha = 1, 
                  decreasing = FALSE,
                  aes.bind='none',
                  #width = 1/20,
                  #knot.pos = 1, 
                  #knot.prop = FALSE
    ) +
    geom_stratum(color='black',
                 fill='white',
                 aes(fill = from_territory)
    ) +
    scale_fill_manual(values = c(# Gaza
                               "#f5b041",
                               # Israel
                               "#1f618d",
                               # Jordan
                               "#e74c3c",
                               # total
                               "lightgray",
                               # west bank
                               "#16a085")
    ) +
    geom_text(stat = "stratum",
              aes(label = after_stat(stratum))
    ) +
    scale_x_discrete(limits = c("Generation", "Demand"),
                     expand = c(0.25, 0.05)
    ) +
    theme_minimal(
    ) + 
    labs(x = "from_id")

# save figure
ggsave("../outputs/figures/oms_sankey.png", 
       width = 22.5, 
       height = 12.5, 
       units = "cm")
# Out:
# plot without title
