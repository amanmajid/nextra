# %%
# ************************************************************************* ----
# Params ----
# ************************************************************************* ----

library(ggplot2)
library(viridis)

# ************************************************************************* ----
# Load data ----
# ************************************************************************* ----

# read data
cost_data = read.csv(file = '../outputs/results/merged_totex_results.csv')

# remove EAG scenario
cost_data = cost_data[cost_data$scenario != 'EAG',]

# adjust territory naming 
cost_data[cost_data$territory == "Gaza", "territory"] <- "GZA"
cost_data[cost_data$territory == "Israel", "territory"] <- "ISR"
cost_data[cost_data$territory == "Jordan", "territory"] <- "JOR"
cost_data[cost_data$territory == "West Bank", "territory"] <- "WBK"

# define precision
cost_data$total = round(cost_data$total,2)

# ************************************************************************* ----
# GRAPH ----
# ************************************************************************* ----

ggplot(cost_data, 
       aes(fill=territory, 
           y=total, 
           x=territory)
    ) + 
    geom_bar(position="dodge",
             stat="identity",
             colour="black",
    ) +
    geom_text(aes(label=total), 
              vjust = -1, 
              color = "darkgray", 
              size = 3,
              fontface = "bold"
    ) +
    scale_fill_manual(values=c(# Gaza
                               "#f5b041",
                               # Israel
                               "#1f618d",
                               # Jordan
                               "#e74c3c",
                               # west bank
                               "#16a085")
    ) +
    facet_wrap(~scenario
    ) +
    theme(legend.position="none"
    ) +
    theme_bw(
    ) + 
    xlab(""
    ) + 
    ylab("Total Expenditure ($USD billion)"
    ) +
    labs(fill=''
    ) +
    scale_y_continuous(limits = c(-0.5, 12)
    )

# save figure
ggsave("../outputs/figures/oms_totex_by_scenario.png", 
       width = 15, 
       height = 12.5, 
       units = "cm")
# Out:
# plot without title

# %%
# Out:
#    scenario territory total
# 1  COO      Gaza      0.05193023
# 2  BAS      Gaza      0.19817122
# 3  COO      West Bank 0.23258210
# 5  BAS      West Bank 0.53611029
# 6  BAS      Jordan    0.97940987
# 7  BAU      Gaza      1.27090032
# 8  BAU      Jordan    2.11299908
# 9  NCO      Jordan    2.16858094
# 11 NCO      Gaza      2.62683188
# 13 BAU      West Bank 4.56214994
# 14 BAS      Israel    5.46962102
# 15 COO      Israel    5.60706304
# 16 COO      Jordan    6.61657542
# 17 NCO      West Bank 8.99610414
# 18 NCO      Israel    9.17838312
# 20 BAU      Israel    9.91501545

# %%
data
# Out:
#    specie   condition value
# 1  sorgho   normal    23.839001
# 2  sorgho   stress     9.789529
# 3  sorgho   Nitrogen  40.090697
# 4  poacee   normal     4.836623
# 5  poacee   stress    14.731154
# 6  poacee   Nitrogen  12.369535
# 7  banana   normal     3.553516
# 8  banana   stress    22.368454
# 9  banana   Nitrogen   2.775688
# 10 triticum normal     8.887239
# 11 triticum stress    22.731307
# 12 triticum Nitrogen   2.639120

# %%
cost_data
# Out:
#    scenario territory total
# 1  COO      Gaza      0.05193023
# 2  BAS      Gaza      0.19817122
# 3  COO      West Bank 0.23258210
# 4  EAG      West Bank 0.50462710
# 5  BAS      West Bank 0.53611029
# 6  BAS      Jordan    0.97940987
# 7  BAU      Gaza      1.27090032
# 8  BAU      Jordan    2.11299908
# 9  NCO      Jordan    2.16858094
# 10 EAG      Gaza      2.62614766
# 11 NCO      Gaza      2.62683188
# 12 EAG      Jordan    3.88579757
# 13 BAU      West Bank 4.56214994
# 14 BAS      Israel    5.46962102
# 15 COO      Israel    5.60706304
# 16 COO      Jordan    6.61657542
# 17 NCO      West Bank 8.99610414
# 18 NCO      Israel    9.17838312
# 19 EAG      Israel    9.17838312
# 20 BAU      Israel    9.91501545
